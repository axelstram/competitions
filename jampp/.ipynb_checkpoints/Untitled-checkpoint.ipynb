# %%
import pandas as pd
import math

from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from collections import OrderedDict, defaultdict
from scipy import sparse
from sklearn.preprocessing import LabelBinarizer
import gc
import lightgbm as lgb
from sklearn.decomposition import TruncatedSVD
#from skopt import gp_minimize

from tqdm import tqdm

from pathlib import PurePath

from fastai.structured import *
import matplotlib.pyplot as plt

import xgboost as xgb

# %%
def group_target_by_fields(df, target, fields = None):
    if fields is None:
        fields = df.columns
    
    target_mean = df[target].mean()
    target_std = df[target].std()
    
    for f in fields:
        gp = df.groupby(f)[target]
        mean = gp.mean()
        std  = gp.std()
        
        if pd.DataFrame(mean).isnull().values.any():
            mean = mean.fillna(target_mean)
            
        if pd.DataFrame(std).isnull().values.any():
            std = std.fillna(target_std)
            
        df[f + '_' + target + '_avg'] = df[f].map(mean)
        df[f + '_' + target + '_std'] = df[f].map(std)

# %%
def objective(space):
    params = {}
    params["tree_method"] = "gpu_hist"
    params['predictor'] = "gpu_predictor"
    params['objective'] = "gpu:reg:linear"
    params['eval_metric'] = "auc"
    params['subsample'] = space['subsample']
    params['colsample_bytree'] = space['colsample_bytree']
    params['colsample_bylevel'] = space['colsample_bylevel']
    params['max_depth'] = int(space['max_depth'])
    params['reg_alpha'] = space['reg_alpha']
    params['reg_lambda'] = space['reg_lambda']
    params['min_child_weight'] = space['min_child_weight']
    params['learning_rate'] = 0.1
    params['scale_pos_weight'] = space['scale_pos_weight']
    params['gamma'] = space['gamma']

    
    print("params: ")
    print("max_depth: " + str(params['max_depth']))
    print("min_child_weight: " + str(params['min_child_weight']))
    print("subsample: " + str(params['subsample']))
    print("reg_alpha: " + str(params['reg_alpha']))
    print("reg_lambda: " + str(params['reg_lambda']))
    print("colsample_bylevel: " + str(params['colsample_bylevel']))
    print("colsample_bytree: " + str(params['colsample_bytree']))
    print("gamma: " + str(params['gamma']))
    print("scale_pos_weight: " + str(space['scale_pos_weight']))
        
    m = xgb.train(params, dtrain, evals=[(dtrain, "train"), (dval, "validation")], num_boost_round=5000,
              early_stopping_rounds=100, verbose_eval=10)
    
    y_pred = m.predict(dval)
    
    print("auc:" + str(sklearn.metrics.roc_auc_score(dval.get_label(), y_pred)))

    return{'loss': sklearn.metrics.auc(dval.get_label(), y_pred), 'status': STATUS_OK }

# %%
PATH = '/home/axel/Desktop/jampp/'

# %%
df_test = pd.read_csv(PATH + '/ctr_test.csv')

# %%
df15 = pd.read_csv(PATH + '/ctr_15.csv')
df16 = pd.read_csv(PATH + '/ctr_16.csv')
df17 = pd.read_csv(PATH + '/ctr_17.csv')
df18 = pd.read_csv(PATH + '/ctr_18.csv')
df19 = pd.read_csv(PATH + '/ctr_19.csv')
df20 = pd.read_csv(PATH + '/ctr_20.csv')
df_val = pd.read_csv(PATH + '/ctr_21.csv')

# %%
df_train = pd.concat([df15, df16, df17, df18, df19, df20, df_val], axis=0)

# %%
del df15; del df16; del df17; del df18; del df19; del df20;
#del df18; del df19; del df20; del df_val;
gc.collect()
# Out:
# 7

# %%
#df_train.info()

# %%
#y_test = df_test['Label']
#df_test.drop(['Label'], inplace=True, axis=1)

# %%
df_all = pd.concat([df_train, df_test], axis=0, keys=['train', 'test'])
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
all_cats = []

for i in tqdm(range(len(df_all))):
    l = df_all['action_list_1'][i]
    
    if type(l) is float:
        l = '[0]'
        
    l = l.split(',')
    cat_list = []
    for i in range(len(l)):
        s = l[i]
        s = s.replace('[', '')
        s = s.replace(',', '')
        s = s.replace(']', '')
        s = s.replace(' ', '')
        cat_list.append(s) 
        
    if len(cat_list) > 7:
        cat_list = cat_list[:5]
    
    while len(cat_list) < 7:
        cat_list.append('0')
    
    all_cats.append(cat_list)
# Out:
# 100%|██████████| 9784231/9784231 [03:04<00:00, 53116.46it/s]

# %%
df = pd.DataFrame(all_cats, columns=['action_cat_1', 'action_cat_2', 'action_cat_3', 'action_cat_4', 'action_cat_5', 'action_cat_6', 'action_cat_7'])

# %%
df = df.reset_index(drop=True)
df_all = df_all.reset_index(drop=True)

# %%
df_all['action_cat_1'] = df['action_cat_1']
df_all['action_cat_2'] = df['action_cat_2']
df_all['action_cat_3'] = df['action_cat_3']
df_all['action_cat_4'] = df['action_cat_4']
df_all['action_cat_5'] = df['action_cat_5']
df_all['action_cat_6'] = df['action_cat_6']
df_all['action_cat_7'] = df['action_cat_7']

# %%
df_all.drop(['id', 'action_list_1'], inplace=True, axis=1)

# %%
all_cats = []

for i in tqdm(range(len(df_all))):
    l = df_all['action_list_2'][i]
    
    if type(l) is float:
        l = '[0]'
        
    l = l.split(',')
    cat_list = []
    for i in range(len(l)):
        s = l[i]
        s = s.replace('[', '')
        s = s.replace(',', '')
        s = s.replace(']', '')
        s = s.replace(' ', '')
        cat_list.append(s) 
        
    if len(cat_list) > 10:
        cat_list = cat_list[:5]
    
    while len(cat_list) < 10:
        cat_list.append('0')
    
    all_cats.append(cat_list)
# Out:
# 100%|██████████| 9784231/9784231 [06:33<00:00, 24885.38it/s]

# %%
df = pd.DataFrame(all_cats, columns=['action_cat_8', 'action_cat_9', 'action_cat_10', 'action_cat_11', 'action_cat_12', 'action_cat_13',
                                     'action_cat_14', 'action_cat_15', 'action_cat_16', 'action_cat_17'])

# %%
df = df.reset_index(drop=True)
df_all = df_all.reset_index(drop=True)

# %%
df_all['action_cat_8'] = df['action_cat_8']
df_all['action_cat_9'] = df['action_cat_9']
df_all['action_cat_10'] = df['action_cat_10']
df_all['action_cat_11'] = df['action_cat_11']
df_all['action_cat_12'] = df['action_cat_12']
df_all['action_cat_13'] = df['action_cat_13']
df_all['action_cat_14'] = df['action_cat_14']
df_all['action_cat_15'] = df['action_cat_15']
df_all['action_cat_16'] = df['action_cat_16']
df_all['action_cat_17'] = df['action_cat_17']

df_all.drop(['action_list_2'], inplace=True, axis=1)

# %%
all_cats = []

for i in tqdm(range(len(df_all))):
    s = df_all['auction_list_0'][i]
    
    if type(s) is float:
        s = ''
        
    cat_list = [cat for cat in s.split("\"") if cat not in ['[', ',', ']']]
    
    if len(cat_list) > 5:
        cat_list = cat_list[:5]
    
    while len(cat_list) < 5:
        cat_list.append('NO_CAT')
    
    all_cats.append(cat_list)
# Out:
# 100%|██████████| 9784231/9784231 [03:30<00:00, 46469.24it/s]

# %%
df = pd.DataFrame(all_cats, columns=['auction_cat_1', 'auction_cat_2', 'auction_cat_3', 'auction_cat_4', 'auction_cat_5'])

# %%
df = df.reset_index(drop=True)
df_all = df_all.reset_index(drop=True)

# %%
df_all['auction_cat_1'] = df['auction_cat_1']
df_all['auction_cat_2'] = df['auction_cat_2']
df_all['auction_cat_3'] = df['auction_cat_3']
df_all['auction_cat_4'] = df['auction_cat_4']
df_all['auction_cat_5'] = df['auction_cat_5']

# %%
df_all.drop(['auction_list_0'], inplace=True, axis=1)

# %%
df_all['creative_area'] = df_all['creative_width'] * df_all['creative_height']

# %%
fields_to_group = ['device_id_type', 'gender', 'auction_age', 'auction_bidfloor',
                   'action_categorical_0', 'action_categorical_1', 'action_categorical_2', 'action_categorical_3',
                   'action_categorical_4', 'action_categorical_5', 'action_categorical_7',
                   'action_list_0', 'auction_cat_1', 'auction_cat_2', 'auction_cat_3', 'auction_cat_4', 'auction_cat_5',
                   'creative_width', 'creative_height', 'creative_area']
group_target_by_fields(df_all, target='Label', fields=fields_to_group)

# %%
le = LabelEncoder()

# Iterate through the columns
for col in df_all:
    if df_all[col].dtype == 'object':
        df_all[col] = le.fit_transform(df_all[col].astype(str))
        # Transform both training and testing data
        #df_train[col] = le.transform(df_train[col].astype(str))
        #df_test[col] = le.transform(df_test[col].astype(str))

# %%
#df_train = df_all.loc['train',:]
#df_test = df_all.loc['test',:]

# %%
#del df_all; del le
#gc.collect()

# %%
# roc_auc = metrics.roc_auc_score(y, y_pred)
# roc_auc

# %%
y_train = df_all['Label']
y_train = [x for x in y_train if str(x) != 'nan']

df_all.drop(['Label'], axis=1, inplace=True)

# %%
corrs = df_all.corr().abs()
upper = corrs.where(np.triu(np.ones(corrs.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
df_all.drop(to_drop, axis=1, inplace=True)

# %%
# df_all.to_feather('/media/axel/ssd/jampp/df_all')
# pd.DataFrame(y_train, columns=['y']).to_feather('/media/axel/ssd/jampp/y_train')

# %%
df_all = pd.read_feather('/media/axel/ssd/jampp/df_all')
y_train = pd.read_feather('/media/axel/ssd/jampp/y_train').values

# %%
y_train = y_train.astype(int).flatten()

# %%
categorical_cols = []
categorical_cols.append(df_all.columns.get_loc("action_list_0"))
categorical_cols.append(df_all.columns.get_loc("device_id_type"))
categorical_cols.append(df_all.columns.get_loc("gender"))
categorical_cols.append(df_all.columns.get_loc("has_video"))


i = 0
for i in range(8):
    if len(df_all['action_categorical_' + str(i)].unique()) < 50:
        categorical_cols.append(df_all.columns.get_loc("action_categorical_" + str(i)))
    
for i in range(13):
    if len(df_all['auction_categorical_' + str(i)].unique()) < 50:
        categorical_cols.append(df_all.columns.get_loc("auction_categorical_" + str(i)))
    
for i in range(13):
    if len(df_all['creative_categorical_' + str(i)].unique()) < 50:
        categorical_cols.append(df_all.columns.get_loc("creative_categorical_" + str(i)))
    
for i in range(1,18):
    if len(df_all['action_cat_' + str(i)].unique()) < 50:
        categorical_cols.append(df_all.columns.get_loc("action_cat_" + str(i)))
    
for i in range(1,6):
    if len(df_all['auction_cat_' + str(i)].unique()) < 50:
        categorical_cols.append(df_all.columns.get_loc("auction_cat_" + str(i)))

# %%
train_full = lgb.Dataset(df_all[:len(y_train)], label=y_train)

train = lgb.Dataset(df_all[:len(y_train)-1523221], label=y_train[:len(y_train)-1523221], categorical_feature=categorical_cols)
val = lgb.Dataset(df_all[len(y_train)-1523221:len(y_train)], label=y_train[len(y_train)-1523221:len(y_train)], categorical_feature=categorical_cols)

test = lgb.Dataset(df_all[len(y_train):], categorical_feature=categorical_cols)

# %%
#del df_all; del le
#gc.collect()

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 3000
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 1
params["bagging_seed"] = 16
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91

# %%
model = lgb.train(params, train, valid_sets=[train, val], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1090: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.830186	valid_1's auc: 0.827022
# [20]	training's auc: 0.837177	valid_1's auc: 0.834437
# [30]	training's auc: 0.841033	valid_1's auc: 0.838006
# [40]	training's auc: 0.844106	valid_1's auc: 0.841097
# [50]	training's auc: 0.8466	valid_1's auc: 0.843332
# ...

# %%
# [650]	training's auc: 0.871825	valid_1's auc: 0.858798

# [390]	training's auc: 0.864758	valid_1's auc: 0.856782  (0.8092)

# [800]	training's auc: 0.882115	valid_1's auc: 0.859889 (0.8121)

# %%
# training's auc: 0.87715	valid_1's auc: 0.863128

# %%
# import shap

# # load JS visualization code to notebook
# shap.initjs()

# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(df_all)

# shap.summary_plot(shap_values, df_all, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
gain = model.feature_importance('gain')
ft = pd.DataFrame({'feature':model.feature_name(), 'split':model.feature_importance('split'), 'gain':100 * gain / gain.sum()}).sort_values('gain', ascending=True)
plt.figure()
ft[['feature','gain']].head(25).plot(kind='barh', x='feature', y='gain', legend=False, figsize=(10, 20))

plt.show(); plt.clf()

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 10
params["bagging_seed"] = 10
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91


model1 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.828765
# [20]	training's auc: 0.835578
# [30]	training's auc: 0.83911
# [40]	training's auc: 0.842485
# [50]	training's auc: 0.84543
# [60]	training's auc: 0.84714
# [70]	training's auc: 0.848267
# [80]	training's auc: 0.849634
# [90]	training's auc: 0.850935
# [100]	training's auc: 0.851948
# [110]	training's auc: 0.852937
# [120]	training's auc: 0.85359
# [130]	training's auc: 0.854401
# [140]	training's auc: 0.855141
# [150]	training's auc: 0.855647
# [160]	training's auc: 0.856466
# [170]	training's auc: 0.857237
# [180]	training's auc: 0.857942
# [190]	training's auc: 0.858272
# [200]	training's auc: 0.858674
# [210]	training's auc: 0.859137
# ...

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 20
params["bagging_seed"] = 20
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91

model2 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.820355
# [20]	training's auc: 0.832067
# [30]	training's auc: 0.837668
# [40]	training's auc: 0.841218
# [50]	training's auc: 0.843774
# [60]	training's auc: 0.845954
# [70]	training's auc: 0.847922
# [80]	training's auc: 0.849173
# [90]	training's auc: 0.850556
# [100]	training's auc: 0.851788
# [110]	training's auc: 0.852997
# [120]	training's auc: 0.854255
# [130]	training's auc: 0.855021
# [140]	training's auc: 0.855495
# [150]	training's auc: 0.856096
# [160]	training's auc: 0.856689
# [170]	training's auc: 0.857248
# [180]	training's auc: 0.857972
# [190]	training's auc: 0.858592
# [200]	training's auc: 0.85897
# [210]	training's auc: 0.859471
# ...

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 30
params["bagging_seed"] = 30
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91

model3 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.829011
# [20]	training's auc: 0.835603
# [30]	training's auc: 0.840433
# [40]	training's auc: 0.844091
# [50]	training's auc: 0.846551
# [60]	training's auc: 0.848137
# [70]	training's auc: 0.849535
# [80]	training's auc: 0.851093
# [90]	training's auc: 0.85189
# [100]	training's auc: 0.853029
# [110]	training's auc: 0.85394
# [120]	training's auc: 0.854801
# [130]	training's auc: 0.855581
# [140]	training's auc: 0.856039
# [150]	training's auc: 0.856826
# [160]	training's auc: 0.857717
# [170]	training's auc: 0.858201
# [180]	training's auc: 0.858572
# [190]	training's auc: 0.859059
# [200]	training's auc: 0.859459
# [210]	training's auc: 0.859884
# ...

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 40
params["bagging_seed"] = 40
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91
model4 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.823653
# [20]	training's auc: 0.832698
# [30]	training's auc: 0.83784
# [40]	training's auc: 0.842483
# [50]	training's auc: 0.845051
# [60]	training's auc: 0.847593
# [70]	training's auc: 0.848942
# [80]	training's auc: 0.850789
# [90]	training's auc: 0.851778
# [100]	training's auc: 0.852676
# [110]	training's auc: 0.853672
# [120]	training's auc: 0.854431
# [130]	training's auc: 0.854936
# [140]	training's auc: 0.855643
# [150]	training's auc: 0.856146
# [160]	training's auc: 0.856661
# [170]	training's auc: 0.857141
# [180]	training's auc: 0.857621
# [190]	training's auc: 0.858135
# [200]	training's auc: 0.858787
# [210]	training's auc: 0.859202
# ...

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 50
params["bagging_seed"] = 50
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91

model5 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.826826
# [20]	training's auc: 0.837347
# [30]	training's auc: 0.84131
# [40]	training's auc: 0.844833
# [50]	training's auc: 0.847325
# [60]	training's auc: 0.849145
# [70]	training's auc: 0.850657
# [80]	training's auc: 0.8516
# [90]	training's auc: 0.852527
# [100]	training's auc: 0.853433
# [110]	training's auc: 0.854376
# [120]	training's auc: 0.854999
# [130]	training's auc: 0.85558
# [140]	training's auc: 0.856021
# [150]	training's auc: 0.856567
# [160]	training's auc: 0.857055
# [170]	training's auc: 0.857527
# [180]	training's auc: 0.858227
# [190]	training's auc: 0.85869
# [200]	training's auc: 0.85921
# [210]	training's auc: 0.859723
# ...

# %%
params = {}

params["objective"] = "binary"
#params["boosting_type"] = "dart"
#params["drop_rate"] = 0.5
params["metric"] = "auc"
params["n_estimators"] = 1800
params["max_depth"] = 5
params["min_data_per_leaf"] = 7000
#params["min_sum_hessian_in_leaf"] = 0.01
params["min_child_weight"] = 30.49
params["num_leaves"] = 20
params["learning_rate"] = 0.22
params["subsample"] = 0.90
params["subsample_freq"] = 1
params["lambda_l1"] = 30
params["lambda_l2"] = 50
#params["min_gain_to_split"] = 0.1
params["feature_fraction"] = 0.20
params["feature_fraction_seed"] = 50
params["bagging_seed"] = 50
params["device"] = "gpu"
params["max_bin"] = 64
#params["scale_pos_weight"] = 72.91

model6 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.826826
# [20]	training's auc: 0.837347
# [30]	training's auc: 0.84131
# [40]	training's auc: 0.844833
# [50]	training's auc: 0.847325
# [60]	training's auc: 0.849145
# [70]	training's auc: 0.850657
# [80]	training's auc: 0.8516
# [90]	training's auc: 0.852527
# [100]	training's auc: 0.853433
# [110]	training's auc: 0.854376
# [120]	training's auc: 0.854999
# [130]	training's auc: 0.85558
# [140]	training's auc: 0.856021
# [150]	training's auc: 0.856567
# [160]	training's auc: 0.857055
# [170]	training's auc: 0.857527
# [180]	training's auc: 0.858227
# [190]	training's auc: 0.85869
# [200]	training's auc: 0.85921
# [210]	training's auc: 0.859723
# ...

# %%
params = {
        "objective" : "regression",
        "metric" : "auc",
        "n_estimators": 500,
        "max_depth": 8, 
        "min_data_per_leaf": 10, 
        "min_child_weight": 10.4985683305030175,
        "num_leaves" : 90, 
        "learning_rate" : 0.07,
        "subsample" : 0.80,
        "subsample_freq" : 10,
        "lambda_l1": 20, 
        "lambda_l2": 50,
        "feature_fraction" : 0.25,
        "bagging_seed" : 70,
        "feature_fraction_seed": 70,
        "device" : "gpu",
        "max_bin": 64,
    }

model7 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.84718
# [20]	training's auc: 0.850621
# [30]	training's auc: 0.853576
# [40]	training's auc: 0.855652
# [50]	training's auc: 0.857388
# [60]	training's auc: 0.858774
# [70]	training's auc: 0.859871
# [80]	training's auc: 0.860489
# [90]	training's auc: 0.861189
# [100]	training's auc: 0.86176
# [110]	training's auc: 0.862715
# [120]	training's auc: 0.863597
# [130]	training's auc: 0.864177
# [140]	training's auc: 0.864565
# [150]	training's auc: 0.864966
# [160]	training's auc: 0.86539
# [170]	training's auc: 0.865956
# [180]	training's auc: 0.866416
# [190]	training's auc: 0.86688
# [200]	training's auc: 0.867312
# [210]	training's auc: 0.867761
# ...

# %%
params = {
        "objective" : "regression",
        "metric" : "auc",
        "n_estimators": 500,
        "max_depth": 8, 
        "min_data_per_leaf": 10, 
        "min_child_weight": 10.4985683305030175,
        "num_leaves" : 90, 
        "learning_rate" : 0.07,
        "subsample" : 0.80,
        "subsample_freq" : 10,
        "lambda_l1": 20, 
        "lambda_l2": 50,
        "feature_fraction" : 0.25,
        "bagging_seed" : 80,
        "feature_fraction_seed": 80,
        "device" : "gpu",
        "max_bin": 64,
    }

model8 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.845528
# [20]	training's auc: 0.84919
# [30]	training's auc: 0.852449
# [40]	training's auc: 0.854733
# [50]	training's auc: 0.856746
# [60]	training's auc: 0.858499
# [70]	training's auc: 0.859698
# [80]	training's auc: 0.860748
# [90]	training's auc: 0.861316
# [100]	training's auc: 0.862119
# [110]	training's auc: 0.862643
# [120]	training's auc: 0.863639
# [130]	training's auc: 0.864359
# [140]	training's auc: 0.865093
# [150]	training's auc: 0.865684
# [160]	training's auc: 0.866049
# [170]	training's auc: 0.866367
# [180]	training's auc: 0.866829
# [190]	training's auc: 0.867204
# [200]	training's auc: 0.867667
# [210]	training's auc: 0.868025
# ...

# %%
params = {
        "objective" : "regression",
        "metric" : "auc",
        "n_estimators": 500,
        "max_depth": 8, 
        "min_data_per_leaf": 10, 
        "min_child_weight": 10.4985683305030175,
        "num_leaves" : 90, 
        "learning_rate" : 0.07,
        "subsample" : 0.80,
        "subsample_freq" : 10,
        "lambda_l1": 20, 
        "lambda_l2": 50,
        "feature_fraction" : 0.25,
        "bagging_seed" : 90,
        "feature_fraction_seed": 90,
        "device" : "gpu",
        "max_bin": 64,
    }

model9 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.848161
# [20]	training's auc: 0.850654
# [30]	training's auc: 0.85347
# [40]	training's auc: 0.855505
# [50]	training's auc: 0.856833
# [60]	training's auc: 0.858347
# [70]	training's auc: 0.859493
# [80]	training's auc: 0.860601
# [90]	training's auc: 0.861286
# [100]	training's auc: 0.862032
# [110]	training's auc: 0.863155
# [120]	training's auc: 0.86395
# [130]	training's auc: 0.864537
# [140]	training's auc: 0.865002
# [150]	training's auc: 0.865687
# [160]	training's auc: 0.866194
# [170]	training's auc: 0.866607
# [180]	training's auc: 0.866969
# [190]	training's auc: 0.867386
# [200]	training's auc: 0.867847
# [210]	training's auc: 0.868275
# ...

# %%
params = {
        "objective" : "regression",
        "metric" : "auc",
        "n_estimators": 500,
        "max_depth": 8, 
        "min_data_per_leaf": 10, 
        "min_child_weight": 10.4985683305030175,
        "num_leaves" : 90, 
        "learning_rate" : 0.07,
        "subsample" : 0.80,
        "subsample_freq" : 10,
        "lambda_l1": 20, 
        "lambda_l2": 50,
        "feature_fraction" : 0.25,
        "bagging_seed" : 100,
        "feature_fraction_seed": 100,
        "device" : "gpu",
        "max_bin": 64,
    }

model10 = lgb.train(params, train_full, valid_sets=[train_full], early_stopping_rounds=100, verbose_eval=10)
# Out:
# /home/axel/anaconda3/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 100 rounds.
# [10]	training's auc: 0.845429
# [20]	training's auc: 0.849196
# [30]	training's auc: 0.852525
# [40]	training's auc: 0.854487
# [50]	training's auc: 0.856421
# [60]	training's auc: 0.858095
# [70]	training's auc: 0.859108
# [80]	training's auc: 0.859966
# [90]	training's auc: 0.861285
# [100]	training's auc: 0.862133
# [110]	training's auc: 0.862983
# [120]	training's auc: 0.863585
# [130]	training's auc: 0.864069
# [140]	training's auc: 0.864771
# [150]	training's auc: 0.865341
# [160]	training's auc: 0.865941
# [170]	training's auc: 0.866518
# [180]	training's auc: 0.867011
# [190]	training's auc: 0.867433
# [200]	training's auc: 0.867771
# [210]	training's auc: 0.868172
# ...

# %%
y_pred1 = model1.predict(test.data, num_iteration=model1.best_iteration)

y_pred2 = model2.predict(test.data, num_iteration=model2.best_iteration)

y_pred3 = model3.predict(test.data, num_iteration=model3.best_iteration)

y_pred4 = model4.predict(test.data, num_iteration=model4.best_iteration)

y_pred5 = model5.predict(test.data, num_iteration=model5.best_iteration)

y_pred6 = model6.predict(test.data, num_iteration=model6.best_iteration)

# %%
dtrain_full = xgb.DMatrix(df_all[:len(y_train)], label=y_train)
dtrain = xgb.DMatrix(df_all[:len(y_train)-1523221], label=y_train[:len(y_train)-1523221])
dval = xgb.DMatrix(df_all[len(y_train)-1523221:len(y_train)], label=y_train[len(y_train)-1523221:len(y_train)])
dtest = xgb.DMatrix(df_all[len(y_train):])

# %%
from hyperopt import *

space = {
        'max_depth': hp.uniform("x_max_depth", 5, 20),
        'min_child_weight': hp.uniform('x_min_child', 1, 5),
        'subsample': hp.uniform('x_subsample', 0.5, 0.95),
        'reg_alpha': hp.uniform('x_reg_alpha', 0, 20),
        'reg_lambda': hp.uniform('x_reg_lambda', 0, 20),
        'colsample_bylevel': hp.uniform('x_colsample_bylevel', 0.2, 0.7),
        'colsample_bytree': hp.uniform('x_colsample_bytree', 0.2, 0.7),
        'gamma': hp.uniform('x_gamma', 0, 1),
        'scale_pos_weight': hp.uniform('x_scale_pos_weight', 0, 100)
    }

# %%
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=7,
            trials=trials)
# Out:
# params:
# max_depth: 15
# min_child_weight: 3.0092001329177647
# subsample: 0.5485333228980671
# reg_alpha: 19.058626427262904
# reg_lambda: 17.780553340067446
# colsample_bylevel: 0.3641070733958466
# colsample_bytree: 0.2512862807454152
# gamma: 0.6873118275580624
# scale_pos_weight: 1.5172553343783424
# [20:24:27] Allocated 544MB on [0] GeForce GTX 980 Ti, 5241MB remaining.
# [20:24:27] Allocated 99MB on [0] GeForce GTX 980 Ti, 5170MB remaining.

# %%
params = {}
params["tree_method"] = "gpu_hist"
params['predictor'] = "gpu_predictor"
params['objective'] = "gpu:reg:linear"
params['eval_metric'] = "auc"
params['subsample'] = 0.8
params['colsample_bytree'] = 0.4
params['colsample_bylevel'] = 0.4
params['max_depth'] = 5
params['reg_alpha'] = 20
params['reg_lambda'] = 20
params['min_child_weight'] = 2
params['learning_rate'] = 0.1
params['scale_pos_weight'] = 72.91
params['gamma'] = 0.5

# %%
m = xgb.train(params, dtrain, evals=[(dtrain, "train"), (dval, "validation")], num_boost_round=1000,
              early_stopping_rounds=100, verbose_eval=10)
# Out:
# [21:03:48] Allocated 544MB on [0] GeForce GTX 980 Ti, 5241MB remaining.
# [21:03:48] Allocated 98MB on [0] GeForce GTX 980 Ti, 5170MB remaining.
# [21:03:48] Allocated 6MB on [0] GeForce GTX 980 Ti, 5164MB remaining.
# [21:03:52] Allocated 1067MB on [0] GeForce GTX 980 Ti, 4063MB remaining.
# [0]	train-auc:0.827128	validation-auc:0.825899
# Multiple eval metrics have been passed: 'validation-auc' will be used for early stopping.
#
# Will train until validation-auc hasn't improved in 100 rounds.
# [10]	train-auc:0.84251	validation-auc:0.840592
# [20]	train-auc:0.84832	validation-auc:0.846503
# [30]	train-auc:0.851759	validation-auc:0.849412
# [40]	train-auc:0.85372	validation-auc:0.85111
# [50]	train-auc:0.855706	validation-auc:0.852711
# [60]	train-auc:0.857641	validation-auc:0.854356
# [70]	train-auc:0.858843	validation-auc:0.855179
# [80]	train-auc:0.860184	validation-auc:0.85608
# [90]	train-auc:0.861798	validation-auc:0.857174
# [100]	train-auc:0.862755	validation-auc:0.8576
# ...

# %%
#[404]	train-auc:0.879351	validation-auc:0.862391

# %%
xgb.plot_importance(m1, max_num_features=15)
xgb.plot_importance(m2, max_num_features=15)

# %%
y_pred = m5.predict(dtest)
#y_pred = np.clip(y_pred, 0, 1)

pd.DataFrame(y_pred).to_csv('xgb5.csv', header=False)
# Out:
# [18:06:56] Allocated 797MB on [0] GeForce GTX 980 Ti, 1896MB remaining.

# %%
# params['seed'] = 2

# m2 = xgb.train(params, dtrain_full, evals=[(dtrain_full, "train")], num_boost_round=500,
#               early_stopping_rounds=100, verbose_eval=10)

# %%
# params['seed'] = 3

# m3 = xgb.train(params, dtrain_full, evals=[(dtrain_full, "train")], num_boost_round=500,
#               early_stopping_rounds=100, verbose_eval=10)

# %%
# params['seed'] = 4

# m4 = xgb.train(params, dtrain_full, evals=[(dtrain_full, "train")], num_boost_round=500,
#               early_stopping_rounds=100, verbose_eval=10)

# %%
# params['seed'] = 5

# m5 = xgb.train(params, dtrain_full, evals=[(dtrain_full, "train")], num_boost_round=500,
#               early_stopping_rounds=100, verbose_eval=10)

# %%
xgb1 = pd.read_csv('xgb1.csv', header=None)
xgb1.drop([0], inplace=True, axis=1)
xgb2 = pd.read_csv('xgb2.csv', header=None)
xgb2.drop([0], inplace=True, axis=1)
xgb3 = pd.read_csv('xgb3.csv', header=None)
xgb3.drop([0], inplace=True, axis=1)
xgb4 = pd.read_csv('xgb4.csv', header=None)
xgb4.drop([0], inplace=True, axis=1)
xgb5 = pd.read_csv('xgb5.csv', header=None)
xgb5.drop([0], inplace=True, axis=1)

# %%
xgb = pd.concat([xgb1, xgb2, xgb3, xgb4, xgb5], axis=1)

# %%
y_pred = xgb.mean(1)
y_pred = np.clip(y_pred, 0, 1)

# %%
d = {'model1': y_pred1, 'model2': y_pred2, 'model3': y_pred3, 'model4': y_pred4, 'model5': y_pred5, 'model6': y_pred6}
df_ens = pd.DataFrame(d)

# %%
#df_ens.to_csv('lgb_ens')

# %%
df_ens.corr()
# Out:
#           model1    model2    model3    model4    model5    model6
# model1  1.000000  0.974644  0.979089  0.970957  0.896789  0.896711
# model2  0.974644  1.000000  0.975277  0.967813  0.886856  0.886769
# model3  0.979089  0.975277  1.000000  0.969228  0.896240  0.896152
# model4  0.970957  0.967813  0.969228  1.000000  0.914753  0.914685
# model5  0.896789  0.886856  0.896240  0.914753  1.000000  0.999999
# model6  0.896711  0.886769  0.896152  0.914685  0.999999  1.000000

# %%
y_pred = df_ens.mean(1)

# %%
df_submission = pd.DataFrame(df_test['id'])

# %%
y_pred = model.predict(test.data, num_iteration=model.best_iteration)
#y_pred = np.clip(y_pred, 0, 1)

# %%
df_submission['pred'] = y_pred

# %%
df_submission.to_csv('../submission.csv', index=False, header=False)
